# %% [markdown]
# # CMPINF0010 Lab Final Project
#
# ## What is the best neighborhood in Pittsburgh?
#
#
# ## Adam Karl, Bailey Mathien

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## POPULATION

# %%
all_pop = pd.read_excel("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/b7156251-6036-4b68-ad2a-95566c84343e/download/opendata-pghsnap-neighborhood-census-data.xlsx")
num_neighborhoods = all_pop["Neighborhood"].count()
all_pop.head()
# Out:
#         Neighborhood  Sector #  Pop. 1940  Pop. 1950  Pop. 1960  Pop. 1970  \
# 0   Allegheny Center         3       4521       3862       2512        632
# 1     Allegheny West         3       3210       3313       2170       1124
# 2          Allentown         6       8227       7487       6416       5361
# 3          Arlington         7       2702       3203       4430       3949
# 4  Arlington Heights         7       2413       2860       2272       2037
#
#    Pop. 1980  Pop. 1990  Pop. 2000  Pop. 2010  ...  % Other (2010)  \
# 0       1586       1262        886        933  ...        0.006431
# 1        820        654        508        462  ...        0.006494
# 2       4292       3600       3220       2500  ...        0.008000
# 3       2294       2210       1999       1869  ...        0.003745
# 4       1466       1497        238        244  ...        0.016393
#
#    % White (2010)  % 2+ Races (2010)  % Hispanic (of any race) (2010)  \
# 0        0.408360             0.0397                            0.029
# 1        0.766234             0.0303                            0.028
# 2        0.594000             0.0464                            0.023
# 3        0.764580             0.0316                            0.014
# 4        0.094262             0.0492                            0.008
#
#    % Pop. Age < 5 (2010)  % Pop. Age 5-19 (2010)  % Pop. Age 20-34 (2010)  \
# 0                 0.0419                  0.2170                   0.2757
# 1                 0.0000                  0.0000                   0.0837
# 2                 0.0366                  0.1485                   0.2411
# 3                 0.0691                  0.1889                   0.1945
# 4                 0.0410                  0.3925                   0.1638
#
#    % Pop. Age 35-59 (2010)  % Pop. Age 60-74 (2010)  % Pop. Age > 75 (2010)
# 0                   0.2243                   0.1761                  0.0650
# 1                   0.6820                   0.1255                  0.1088
# 2                   0.3530                   0.1440                  0.0767
# 3                   0.3153                   0.0888                  0.1433
# 4                   0.3072                   0.0341                  0.0614
#
# [5 rows x 34 columns]

# %%
pop = all_pop.filter(["Neighborhood","Pop. 2010"])
pop = pop.rename(columns={pop.columns[1]:"population"})
pop.sort_values(by=["population"], ascending=False)
# Out:
#            Neighborhood  population
# 76  Squirrel Hill South       15110
# 67            Shadyside       13915
# 13            Brookline       13214
# 75  Squirrel Hill North       11363
# 55        North Oakland       10551
# ..                  ...         ...
# 86             West End         254
# 4     Arlington Heights         244
# 77            St. Clair         209
# 70          South Shore          19
# 21              Chateau          11
#
# [90 rows x 2 columns]

# %% [markdown]
# # Playgrounds

# %%
all_playgrounds = pd.read_csv("https://data.wprdc.org/datastore/dump/47350364-44a8-4d15-b6e0-5f79ddff9367")  
all_playgrounds
# Out:
#              id                           name  type  \
# 0     731501774           Able Long Playground   NaN
# 1    1461276747       Albert Graham Playground   NaN
# 2    1860709784              Alpine Playground   NaN
# 3    1770671485               Alton Playground   NaN
# 4      18942817               Ammon Playground   NaN
# ..          ...                            ...   ...
# 116   680315308            Wightman Playground   NaN
# 117  1998890669             Winters Playground   NaN
# 118   815926730           Woods Run Playground   NaN
# 119  1137558943  Martin Luther King Playground   NaN
# 120  1199980206      Phillips Lower Playground   NaN
#
#     maintenance_responsibility                     park       street  \
# 0              Parks - Western           Able Long Park    COAST AVE
# 1             Parks - Schenley  Albert Turk Graham Park  FORESIDE PL
# 2             Parks - Northern      Alpine Gardens Park   ALPINE AVE
# 3              Parks - Western               Alton Park   ANDICK WAY
# 4             Parks - Schenley               Ammon Park    MEMORY LN
# ..                         ...                      ...          ...
# 116            Parks - Eastern            Wightman Park    SOLWAY ST
# 117           Parks - Southern             Winters Park     HURON ST
# 118           Parks - Northern           Woods Run Park  CENTRAL AVE
# 119           Parks - Northern        Allegheny Commons  E NORTH AVE
# 120                        NaN                      NaN          NaN
#
#                                                  image         neighborhood  \
# 0    https://tools.wprdc.org/images/pittsburgh/play...            Beechview
# 1    https://tools.wprdc.org/images/pittsburgh/play...     Crawford-Roberts
# 2    https://tools.wprdc.org/images/pittsburgh/play...    Central Northside
# 3    https://tools.wprdc.org/images/pittsburgh/play...            Beechview
# 4    https://tools.wprdc.org/images/pittsburgh/play...    Bedford Dwellings
# ..                                                 ...                  ...
# 116  https://tools.wprdc.org/images/pittsburgh/play...  Squirrel Hill North
# 117  https://tools.wprdc.org/images/pittsburgh/play...    South Side Slopes
# 118  https://tools.wprdc.org/images/pittsburgh/play...   Marshall-Shadeland
# 119  https://tools.wprdc.org/images/pittsburgh/play...     Allegheny Center
# 120                                                NaN              Carrick
#
#      council_district  ward        tract  public_works_division  pli_division  \
# 0                   4    19  42003192000                      5            19
# 1                   6     3  42003030500                      3             3
# 2                   6    25  42003250300                      1            25
# 3                   4    19  42003191600                      5            19
# 4                   6     5  42003050900                      3             5
# ..                ...   ...          ...                    ...           ...
# 116                 8    14  42003140300                      3            14
# 117                 3    17  42003170600                      3            17
# 118                 1    27  42003271500                      1            27
# 119                 1    22  42003562700                      1            22
# 120                 4    29  42003290400                      3            29
#
#      police_zone fire_zone   latitude  longitude
# 0              6      4-28  40.408365 -80.028445
# 1              2       2-1  40.440519 -79.984137
# 2              1      1-21  40.457707 -80.012952
# 3              6      4-28  40.414137 -80.021831
# 4              2       2-5  40.449037 -79.978064
# ..           ...       ...        ...        ...
# 116            4      2-18  40.443330 -79.926454
# 117            3       4-3  40.422932 -79.981292
# 118            1      1-14  40.476348 -80.029265
# 119            1       1-6  40.455281 -80.004696
# 120            3      4-23  40.388144 -79.990309
#
# [121 rows x 17 columns]

# %% [markdown]
# **Combine with population data**

# %%
total = pop
total["num_playgrounds"] = 0
for index, row in all_playgrounds.iterrows():
    name = row.iloc[7]
    total.loc[total["Neighborhood"] == name, "num_playgrounds"] += 1
total.sort_values(by=["num_playgrounds"], ascending=False)
# Out:
#             Neighborhood  population  num_playgrounds
# 76   Squirrel Hill South       15110                8
# 72     South Side Slopes        4423                5
# 7              Beechview        7974                5
# 0       Allegheny Center         933                4
# 68              Sheraden        5299                4
# ..                   ...         ...              ...
# 14  California-Kirkbride         761                0
# 59             Overbrook        3644                0
# 25        East Allegheny        2136                0
# 56           North Shore         303                0
# 57     Northview Heights        1214                0
#
# [90 rows x 3 columns]

# %% [markdown]
# **Calculate Playgrounds/population**

# %%
total.loc[0, "playgrounds per 1000 people"] = 0
total["playgrounds per 1000 people"] = total["num_playgrounds"].divide(total["population"], fill_value=0)
total["playgrounds per 1000 people"] *= 1000
total["playgrounds per 1000 people"] = total["playgrounds per 1000 people"]
total.sort_values(by=["playgrounds per 1000 people"], ascending=False)
# Out:
#                  Neighborhood  population  num_playgrounds  \
# 0            Allegheny Center         933                4
# 86                   West End         254                1
# 30                     Esplen         301                1
# 37                       Hays         362                1
# 26              East Carnegie         570                1
# ..                        ...         ...              ...
# 57          Northview Heights        1214                0
# 59                  Overbrook        3644                0
# 62               Point Breeze        5315                0
# 14       California-Kirkbride         761                0
# 16  Central Business District        3629                0
#
#     playgrounds per 1000 people
# 0                      4.287245
# 86                     3.937008
# 30                     3.322259
# 37                     2.762431
# 26                     1.754386
# ..                          ...
# 57                     0.000000
# 59                     0.000000
# 62                     0.000000
# 14                     0.000000
# 16                     0.000000
#
# [90 rows x 4 columns]

# %% [markdown]
# **Calculate Playgrounds Rank**
#
# Playgrounds/1000 residents Data Analysis:
#
# mean: 0.5977
#
# standard deviation: 0.7817
#
# max: Allegheny Center, 4 playgrounds (4.29 / 1000 people), +4.7198 rank
#
# min: (several neighborhoods), 0 playgrounds, -0.7647 rank

# %%
pg_mean = np.nansum(total.loc[:, "playgrounds per 1000 people"]) / num_neighborhoods
total["temp_stdDev"] = np.square(total["playgrounds per 1000 people"] - pg_mean)
pg_stdDev = np.sqrt(np.nansum(total.loc[:, "temp_stdDev"]) / num_neighborhoods)
total["playgrounds_rank"] = (total["playgrounds per 1000 people"] - pg_mean)/pg_stdDev
total.sort_values(by=["playgrounds per 1000 people"], ascending=False)
# Out:
#                  Neighborhood  population  num_playgrounds  \
# 0            Allegheny Center         933                4
# 86                   West End         254                1
# 30                     Esplen         301                1
# 37                       Hays         362                1
# 26              East Carnegie         570                1
# ..                        ...         ...              ...
# 57          Northview Heights        1214                0
# 59                  Overbrook        3644                0
# 62               Point Breeze        5315                0
# 14       California-Kirkbride         761                0
# 16  Central Business District        3629                0
#
#     playgrounds per 1000 people  temp_stdDev  playgrounds_rank
# 0                      4.287245    13.612181          4.719792
# 86                     3.937008    11.150466          4.271747
# 30                     3.322259     7.422805          3.485323
# 37                     2.762431     4.685729          2.769157
# 26                     1.754386     1.337745          1.479605
# ..                          ...          ...               ...
# 57                     0.000000     0.357337         -0.764712
# 59                     0.000000     0.357337         -0.764712
# 62                     0.000000     0.357337         -0.764712
# 14                     0.000000     0.357337         -0.764712
# 16                     0.000000     0.357337         -0.764712
#
# [90 rows x 6 columns]

# %%
total = total.filter(["Neighborhood", "population", "playgrounds_rank"])
total
# Out:
#            Neighborhood  population  playgrounds_rank
# 0      Allegheny Center         933          4.719792
# 1        Allegheny West         462         -0.764712
# 2             Allentown        2500         -0.253008
# 3             Arlington        1869         -0.764712
# 4     Arlington Heights         244         -0.764712
# ..                  ...         ...               ...
# 85  Upper Lawrenceville        2669          0.193895
# 86             West End         254          4.271747
# 87         West Oakland        2604         -0.273444
# 88             Westwood        3066         -0.347471
# 89              Windgap        1369          0.169737
#
# [90 rows x 3 columns]

# %%
pg_plot = total.sort_values(by=["playgrounds_rank"], ascending=False).plot.bar(x="Neighborhood", y="playgrounds_rank")

# %% [markdown]
# ## Income

# %%
income = pd.read_csv("https://data.wprdc.org/dataset/5b18c198-474c-4723-b735-cc5220ad43cc/resource/34842307-0da6-458a-9df3-a09ab3e3a489/download/aggregate-household-income-in-the-past-12-months-in-2015-inflation-adjusted-dollars.csv")
income.head()
# Out:
#         Neighborhood  Id  \
# 0   Allegheny Center   1
# 1     Allegheny West   2
# 2          Allentown   3
# 3          Arlington   4
# 4  Arlington Heights   5
#
#   Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)  \
# 0                                           39947000
# 1                                           23793300
# 2                                           38303700
# 3                                           35349900
# 4                                            2389600
#
#   Margin of Error; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)
# 0                                            6437773
# 1                                           22025939
# 2                                        7490207.043
# 3                                        6140662.723
# 4                                            1162393

# %%
income = income.filter(["Neighborhood","Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)"])
income = income.rename(columns={"Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)":"aggregate household income"})
income.loc[income["Neighborhood"] == "Chateau", "aggregate household income"] = '0'
income.loc[income["Neighborhood"] == "South Shore", "aggregate household income"] = '0'
income["aggregate household income"] = income["aggregate household income"].apply(pd.to_numeric)
income.sort_values(by=["aggregate household income"], ascending=True)
# Out:
#            Neighborhood  aggregate household income
# 21              Chateau                           0
# 71          South Shore                           0
# 4     Arlington Heights                     2389600
# 87             West End                     3615800
# 78            St. Clair                     3867600
# ..                  ...                         ...
# 63         Point Breeze                   314958500
# 13            Brookline                   366945900
# 76  Squirrel Hill North                   577467500
# 68            Shadyside                   605635700
# 77  Squirrel Hill South                   659886300
#
# [91 rows x 2 columns]

# %%
new_total = pd.merge(left=total, right=income, left_on='Neighborhood', right_on='Neighborhood')
new_total["income by population"] = new_total["aggregate household income"].divide(new_total["population"], fill_value=0)
new_total.sort_values(by=["income by population"], ascending=False)
# Out:
#                  Neighborhood  population  playgrounds_rank  \
# 79             Strip District         616          1.312010
# 62               Point Breeze        5315         -0.764712
# 16  Central Business District        3629         -0.764712
# 65              Regent Square         928          0.613802
# 1              Allegheny West         462         -0.764712
# ..                        ...         ...               ...
# 87               West Oakland        2604         -0.273444
# 82            Terrace Village        3228         -0.368411
# 10                      Bluff        6600         -0.570885
# 70                South Shore          19         -0.764712
# 21                    Chateau          11         -0.764712
#
#     aggregate household income  income by population
# 79                    91738300         148925.811688
# 62                   314958500          59258.419567
# 16                   210460000          57993.937724
# 65                    52288700          56345.581897
# 1                     23793300          51500.649351
# ..                         ...                   ...
# 87                    16339500           6274.769585
# 82                    16879300           5229.027261
# 10                    11005200           1667.454545
# 70                           0              0.000000
# 21                           0              0.000000
#
# [90 rows x 5 columns]

# %% [markdown]
# **Calculate Income Rank**
#
# Income/population Data Analysis:
#
# mean: $25,253
#
# standard deviation: $17,994
#
# max: Strip District, $148,926 / person, +6.873 rank
#
# min: South Shore & Chateau, $0 / person, -1.403 rank

# %%
total = new_total
inc_mean = np.nansum(total.loc[:, "income by population"]) / num_neighborhoods
total["temp_stdDev"] = np.square(total["income by population"] - inc_mean)
inc_stdDev = np.sqrt(np.nansum(total.loc[:, "temp_stdDev"]) / num_neighborhoods)
total["income_rank"] = (total["income by population"] - inc_mean)/inc_stdDev

total.sort_values(by=["income by population"], ascending=False)
# Out:
#                  Neighborhood  population  playgrounds_rank  \
# 79             Strip District         616          1.312010
# 62               Point Breeze        5315         -0.764712
# 16  Central Business District        3629         -0.764712
# 65              Regent Square         928          0.613802
# 1              Allegheny West         462         -0.764712
# ..                        ...         ...               ...
# 87               West Oakland        2604         -0.273444
# 82            Terrace Village        3228         -0.368411
# 10                      Bluff        6600         -0.570885
# 70                South Shore          19         -0.764712
# 21                    Chateau          11         -0.764712
#
#     aggregate household income  income by population   temp_stdDev  \
# 79                    91738300         148925.811688  1.529492e+10
# 62                   314958500          59258.419567  1.156356e+09
# 16                   210460000          57993.937724  1.071957e+09
# 65                    52288700          56345.581897  9.667371e+08
# 1                     23793300          51500.649351  6.889294e+08
# ..                         ...                   ...           ...
# 87                    16339500           6274.769585  3.601803e+08
# 82                    16879300           5229.027261  4.009669e+08
# 10                    11005200           1667.454545  5.562867e+08
# 70                           0              0.000000  6.377234e+08
# 21                           0              0.000000  6.377234e+08
#
#     income_rank
# 79     6.872869
# 62     1.889776
# 16     1.819505
# 65     1.727900
# 1      1.458653
# ..          ...
# 87    -1.054689
# 82    -1.112804
# 10    -1.310732
# 70    -1.403397
# 21    -1.403397
#
# [90 rows x 7 columns]

# %%
total = total.filter(["Neighborhood", "playgrounds_rank", "income_rank"])
total
# Out:
#            Neighborhood  playgrounds_rank  income_rank
# 0      Allegheny Center          4.719792     0.976000
# 1        Allegheny West         -0.764712     1.458653
# 2             Allentown         -0.253008    -0.551935
# 3             Arlington         -0.764712    -0.352299
# 4     Arlington Heights         -0.764712    -0.859146
# ..                  ...               ...          ...
# 85  Upper Lawrenceville          0.193895    -0.034611
# 86             West End          4.271747    -0.612290
# 87         West Oakland         -0.273444    -1.054689
# 88             Westwood         -0.347471     0.261568
# 89              Windgap          0.169737     0.001530
#
# [90 rows x 3 columns]

# %%
pg_plot = total.sort_values(by=["income_rank"], ascending=False).plot.bar(x="Neighborhood", y="income_rank")

# %% [markdown]
# ## Environmental Factors

# %%
environment = pd.read_excel("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/9c46a88c-8fca-4839-9848-c2b819ecbf0f/download/natural-environment-conditions.xls")
environment.head()
# Out:
#         Neighborhood  Sector #  Population (2010)  Land Area (acres)  \
# 0   Allegheny Center         3                933             134.40
# 1     Allegheny West         3                462              90.24
# 2          Allentown         6               2500             188.80
# 3          Arlington         7               1869             300.80
# 4  Arlington Heights         7                244              84.48
#
#    Landslide Prone (% land area)  Undermined (% land area)  \
# 0                       0.000000                  0.000000
# 1                       0.093273                  0.000000
# 2                       0.270911                  0.903528
# 3                       0.414182                  0.572543
# 4                       0.398935                  0.611955
#
#    Flood Plain (% land area)  # Street Trees  Park Space (acres)  \
# 0                   0.001637              22              55.264
# 1                   0.023105             229               7.182
# 2                   0.000000              87              39.385
# 3                   0.015170              79               6.747
# 4                   0.000000               3               0.000
#
#    Park Space (% of land area)  Park Space (acres/1000 pers.)  \
# 0                     0.411190                      59.232583
# 1                     0.079588                      15.545455
# 2                     0.208607                      15.754000
# 3                     0.022430                       3.609952
# 4                     0.000000                       0.000000
#
#    Greenway (% of land area)  Woodland (% of land area)  \
# 0                        0.0                   0.000000
# 1                        0.0                   0.042354
# 2                        0.0                   0.123093
# 3                        0.0                   0.294289
# 4                        0.0                   0.417969
#
#    Cemetery (% of land area)
# 0                   0.000000
# 1                   0.000000
# 2                   0.000000
# 3                   0.073075
# 4                   0.000000

# %%
environment = environment.filter(["Neighborhood","Landslide Prone (% land area)", "Flood Plain (% land area)"])
environment["risk area"] = environment.loc[:,["Landslide Prone (% land area)", "Flood Plain (% land area)"]].sum(axis=1)
environment.sort_values(by=["risk area"], ascending=True)
# Out:
#           Neighborhood  Landslide Prone (% land area)  \
# 33          Friendship                       0.000000
# 40      Homewood North                       0.000000
# 63  Point Breeze North                       0.000000
# 41      Homewood South                       0.000000
# 27          East Hills                       0.000000
# ..                 ...                            ...
# 79      Strip District                       0.109380
# 72   South Side Slopes                       0.663595
# 64         Polish Hill                       0.750000
# 56         North Shore                       0.000000
# 32            Fineview                       0.919600
#
#     Flood Plain (% land area)  risk area
# 33                   0.000000   0.000000
# 40                   0.000000   0.000000
# 63                   0.000000   0.000000
# 41                   0.000000   0.000000
# 27                   0.000000   0.000000
# ..                        ...        ...
# 79                   0.542211   0.651591
# 72                   0.000000   0.663595
# 64                   0.003799   0.753799
# 56                   0.819585   0.819585
# 32                   0.000000   0.919600
#
# [90 rows x 4 columns]

# %%
environment = environment.filter(["Neighborhood", "risk area"])
environment
# Out:
#            Neighborhood  risk area
# 0      Allegheny Center   0.001637
# 1        Allegheny West   0.116379
# 2             Allentown   0.270911
# 3             Arlington   0.429352
# 4     Arlington Heights   0.398935
# ..                  ...        ...
# 85  Upper Lawrenceville   0.258187
# 86             West End   0.422039
# 87         West Oakland   0.645349
# 88             Westwood   0.152369
# 89              Windgap   0.131653
#
# [90 rows x 2 columns]

# %% [markdown]
# **Calculate Environment Rank**
#
# Risk Area Data Analysis:
#
# mean: 27% risk area
#
# standard deviation: 22%
#
# max: (several neighborhoods), 0% risk area, +1.236 rank
#
# min: Fineview, 91.9% risk area, -2.949 rank

# %%
env_mean = np.nansum(environment.loc[:, "risk area"]) / num_neighborhoods
environment["temp_stdDev"] = np.square(environment["risk area"] - env_mean)
env_stdDev = np.sqrt(np.nansum(environment.loc[:, "temp_stdDev"]) / num_neighborhoods)

environment["environment_rank"] = ((environment["risk area"] - env_mean)/env_stdDev)*-1

environment.sort_values(by=["environment_rank"], ascending=False)
# Out:
#           Neighborhood  risk area  temp_stdDev  environment_rank
# 27          East Hills   0.000000     0.073777          1.236097
# 58             Oakwood   0.000000     0.073777          1.236097
# 33          Friendship   0.000000     0.073777          1.236097
# 40      Homewood North   0.000000     0.073777          1.236097
# 63  Point Breeze North   0.000000     0.073777          1.236097
# ..                 ...        ...          ...               ...
# 79      Strip District   0.651591     0.144379         -1.729199
# 72   South Side Slopes   0.663595     0.153646         -1.783831
# 64         Polish Hill   0.753799     0.232498         -2.194334
# 56         North Shore   0.819585     0.300268         -2.493718
# 32            Fineview   0.919600     0.419880         -2.948870
#
# [90 rows x 4 columns]

# %%
environment = environment.filter(["Neighborhood", "environment_rank"])
pg_plot = environment.sort_values(by=["environment_rank"], ascending=False).plot.bar(x="Neighborhood", y="environment_rank")

# %% [markdown]
# **merge with total**

# %%
new_total = pd.merge(left=total, right=environment, left_on='Neighborhood', right_on='Neighborhood')

# %%
total = new_total
total
# Out:
#            Neighborhood  playgrounds_rank  income_rank  environment_rank
# 0      Allegheny Center          4.719792     0.976000          1.228647
# 1        Allegheny West         -0.764712     1.458653          0.706475
# 2             Allentown         -0.253008    -0.551935          0.003220
# 3             Arlington         -0.764712    -0.352299         -0.717821
# 4     Arlington Heights         -0.764712    -0.859146         -0.579397
# ..                  ...               ...          ...               ...
# 85  Upper Lawrenceville          0.193895    -0.034611          0.061126
# 86             West End          4.271747    -0.612290         -0.684542
# 87         West Oakland         -0.273444    -1.054689         -1.700793
# 88             Westwood         -0.347471     0.261568          0.542689
# 89              Windgap          0.169737     0.001530          0.636963
#
# [90 rows x 4 columns]

# %% [markdown]
# ## Final Calculations

# %%
total["final_score"] = total["playgrounds_rank"] + total["income_rank"] + total["environment_rank"]
pd.set_option('display.max_rows', None)
total.sort_values(by=["final_score"], ascending=False)
# Out:
#                  Neighborhood  playgrounds_rank  income_rank  \
# 0            Allegheny Center          4.719792     0.976000
# 79             Strip District          1.312010     6.872869
# 30                     Esplen          3.485323    -0.400146
# 86                   West End          4.271747    -0.612290
# 26              East Carnegie          1.479605     0.053690
# 62               Point Breeze         -0.764712     1.889776
# 75        Squirrel Hill North         -0.652131     1.420826
# 65              Regent Square          0.613802     1.727900
# 48                 Manchester          0.436472     0.015209
# 58                    Oakwood          0.480917    -0.049790
# 67                  Shadyside         -0.672778     1.015362
# 1              Allegheny West         -0.764712     1.458653
# 31                  Fairywood          0.511995     0.477236
# 63         Point Breeze North         -0.141898     0.208393
# 18          Central Northside          0.110595     0.428509
# 42              Homewood West          0.799176    -0.636380
# 39              Highland Park          0.035451     0.703126
# 37                       Hays          2.769157    -0.415947
# 76        Squirrel Hill South         -0.087407     1.023599
# 45              Lincoln Place          0.028136     0.052695
# 8                 Beltzhoover          1.228941    -0.591560
# 5                  Banksville         -0.456010     0.448387
# 16  Central Business District         -0.764712     1.819505
# 89                    Windgap          0.169737     0.001530
# 50                Middle Hill         -0.015292    -0.505952
# 34                   Garfield         -0.068516    -0.380659
# 9                  Bloomfield         -0.461641     0.241669
# 13                  Brookline         -0.571090     0.139838
# 28               East Liberty         -0.328774    -0.307733
# 36                 Greenfield         -0.413941     0.435664
# 33                 Friendship         -0.764712     0.074672
# 23           Crawford-Roberts          0.936432    -0.560278
# 54              New Homestead          0.527470     0.115746
# 88                   Westwood         -0.347471     0.261568
# 71           South Side Flats         -0.376881     0.560222
# 7                   Beechview          0.037433    -0.057936
# 15                    Carrick         -0.385222    -0.187740
# 59                  Overbrook         -0.764712    -0.028615
# 85        Upper Lawrenceville          0.193895    -0.034611
# 11                    Bon Air          0.818531     0.116134
# 53                 Mt. Oliver         -0.764712     0.121063
# 78            Stanton Heights         -0.486672     0.215688
# 40             Homewood North         -0.374693    -0.764183
# 51                Morningside         -0.000061     0.056037
# 52           Mount Washington         -0.328551     0.283568
# 25             East Allegheny         -0.764712     0.064843
# 43                  Knoxville         -0.764712    -0.505547
# 44                    Larimer         -0.024399    -0.820031
# 20             Chartiers City         -0.764712     0.204983
# 29                    Elliott          0.847124    -0.394728
# 27                 East Hills         -0.764712    -0.675139
# 41             Homewood South         -0.764712    -0.705547
# 69              South Oakland          0.527906    -0.510142
# 24           Duquesne Heights         -0.237182     0.696080
# 46   Lincoln-Lemington-Belmar         -0.240747    -0.367358
# 38                  Hazelwood          0.124281    -0.427245
# 47        Lower Lawrenceville         -0.218253     0.105525
# 17      Central Lawrenceville         -0.479290     0.393464
# 81             Swisshelm Park          0.175230     0.356305
# 22            Crafton Heights         -0.093888    -0.102536
# 12           Brighton Heights         -0.411666     0.143269
# 68                   Sheraden          0.200950    -0.343306
# 19            Central Oakland         -0.554515    -0.896352
# 2                   Allentown         -0.253008    -0.551935
# 83                  Troy Hill          0.178000     0.183970
# 6           Bedford Dwellings          0.299565    -0.916597
# 82            Terrace Village         -0.368411    -1.112804
# 72          South Side Slopes          0.681434     0.150191
# 73              Spring Garden          0.682415    -0.407998
# 84                 Upper Hill         -0.142806    -0.335897
# 14       California-Kirkbride         -0.764712    -0.620635
# 55              North Oakland         -0.764712    -0.753392
# 80                Summer Hill         -0.764712     0.729504
# 61                Perry South         -0.456084    -0.666138
# 66                  Ridgemont         -0.764712    -0.495140
# 10                      Bluff         -0.570885    -1.310732
# 64                Polish Hill          0.239417     0.292973
# 3                   Arlington         -0.764712    -0.352299
# 60                Perry North         -0.448845     0.025145
# 77                  St. Clair         -0.764712    -0.375003
# 74      Spring Hill-City View         -0.281607    -0.423554
# 4           Arlington Heights         -0.764712    -0.859146
# 57          Northview Heights         -0.764712    -1.002621
# 56                North Shore         -0.764712     0.870330
# 49         Marshall-Shadeland         -0.341326    -0.770033
# 32                   Fineview          0.230822    -0.301645
# 87               West Oakland         -0.273444    -1.054689
# 35                 Glen Hazel         -0.764712    -1.032913
# 21                    Chateau         -0.764712    -1.403397
# 70                South Shore         -0.764712    -1.403397
#
#     environment_rank  final_score
# 0           1.228647     6.924439
# 79         -1.729199     6.455680
# 30         -0.059321     3.025856
# 86         -0.684542     2.974914
# 26          1.045013     2.578307
# 62          1.062854     2.187918
# 75          1.216836     1.985531
# 65         -0.378257     1.963445
# 48          1.233497     1.685177
# 58          1.236097     1.667224
# 67          1.186491     1.529076
# 1           0.706475     1.400415
# 31          0.408363     1.397594
# 63          1.236097     1.302591
# 18          0.679402     1.218505
# 42          1.052433     1.215229
# 39          0.473985     1.212562
# 37         -1.196636     1.156574
# 76          0.177591     1.113783
# 45          0.976729     1.057560
# 8           0.367897     1.005278
# 5           0.947133     0.939510
# 16         -0.156159     0.898634
# 89          0.636963     0.808230
# 50          1.234511     0.713267
# 34          1.125608     0.676434
# 9           0.868598     0.648626
# 13          1.056645     0.625393
# 28          1.200457     0.563951
# 36          0.531557     0.553279
# 33          1.236097     0.546057
# 23          0.113266     0.489420
# 54         -0.168412     0.474804
# 88          0.542689     0.456786
# 71          0.262742     0.446083
# 7           0.361260     0.340757
# 15          0.903984     0.331022
# 59          1.057024     0.263697
# 85          0.061126     0.220410
# 11         -0.761854     0.172811
# 53          0.816067     0.172418
# 78          0.418423     0.147438
# 40          1.236097     0.097220
# 51         -0.012894     0.043082
# 52          0.078516     0.033534
# 25          0.729850     0.029981
# 43          1.230634    -0.039625
# 44          0.780004    -0.064426
# 20          0.412870    -0.146859
# 29         -0.626933    -0.174538
# 27          1.236097    -0.203754
# 41          1.236097    -0.234163
# 69         -0.261996    -0.244232
# 24         -0.796825    -0.337927
# 46          0.248571    -0.359534
# 38         -0.078011    -0.380974
# 47         -0.339125    -0.451853
# 17         -0.386778    -0.472603
# 81         -1.132748    -0.601213
# 22         -0.417238    -0.613662
# 12         -0.349624    -0.618021
# 68         -0.505948    -0.648304
# 19          0.754061    -0.696805
# 2           0.003220    -0.801724
# 83         -1.175223    -0.813253
# 6          -0.292746    -0.909778
# 82          0.566525    -0.914689
# 72         -1.783831    -0.952206
# 73         -1.244146    -0.969728
# 84         -0.516592    -0.995295
# 14          0.342572    -1.042775
# 55          0.419975    -1.098129
# 80         -1.167405    -1.202613
# 61         -0.214827    -1.337049
# 66         -0.114958    -1.374810
# 10          0.349323    -1.532293
# 64         -2.194334    -1.661944
# 3          -0.717821    -1.834832
# 60         -1.448279    -1.871979
# 77         -0.911935    -2.051650
# 74         -1.368038    -2.073200
# 4          -0.579397    -2.203255
# 57         -0.493079    -2.260412
# 56         -2.493718    -2.388100
# 49         -1.524055    -2.635414
# 32         -2.948870    -3.019694
# 87         -1.700793    -3.028926
# 35         -1.515998    -3.313623
# 21         -1.344609    -3.512718
# 70         -1.493813    -3.661922

# %% [markdown]
# **All neighborhoods**

# %%
graph1 = total.sort_values(by=["final_score"], ascending=False).plot.bar(x="Neighborhood", y="final_score")

# %% [markdown]
# **Worst Neighborhoods**

# %%
graph2 = total.sort_values(by=["final_score"], ascending=True).head().plot.bar(x="Neighborhood")

# %% [markdown]
# **Best Neighborhoods**

# %%
graph3 = total.sort_values(by=["final_score"], ascending=False).head().plot.bar(x="Neighborhood")
